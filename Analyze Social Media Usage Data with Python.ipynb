# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('social_media_usage.csv')

# %%
df1
# Out:
#     User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0       U_1  Pinterest                  288             16             94
# 1       U_2   Facebook                  192             14            117
# 2       U_3  Instagram                  351             13            120
# 3       U_4     TikTok                   21             20            117
# 4       U_5   LinkedIn                  241             16              9
# ..      ...        ...                  ...            ...            ...
# 995   U_996   LinkedIn                  479              4             72
# 996   U_997  Instagram                  499             14            110
# 997   U_998   Facebook                  318              6            105
# 998   U_999     TikTok                  305             15            151
# 999  U_1000  Pinterest                  115             17             81
#
#      Follows_Per_Day
# 0                  0
# 1                 15
# ...

# %%
df1.head()
# Out:
#   User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0     U_1  Pinterest                  288             16             94
# 1     U_2   Facebook                  192             14            117
# 2     U_3  Instagram                  351             13            120
# 3     U_4     TikTok                   21             20            117
# 4     U_5   LinkedIn                  241             16              9
#
#    Follows_Per_Day
# 0                0
# 1               15
# 2               48
# 3                8
# 4               21

# %%
df1.dtypes
# Out:
# User_ID                object
# App                    object
# Daily_Minutes_Spent     int64
# Posts_Per_Day           int64
# Likes_Per_Day           int64
# Follows_Per_Day         int64
# dtype: object

# %%
df1.isnull
# Out:
# <bound method DataFrame.isnull of     User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0       U_1  Pinterest                  288             16             94
# 1       U_2   Facebook                  192             14            117
# 2       U_3  Instagram                  351             13            120
# 3       U_4     TikTok                   21             20            117
# 4       U_5   LinkedIn                  241             16              9
# ..      ...        ...                  ...            ...            ...
# 995   U_996   LinkedIn                  479              4             72
# 996   U_997  Instagram                  499             14            110
# 997   U_998   Facebook                  318              6            105
# 998   U_999     TikTok                  305             15            151
# 999  U_1000  Pinterest                  115             17             81
#
#      Follows_Per_Day
# 0                  0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User_ID              1000 non-null   object
#  1   App                  1000 non-null   object
#  2   Daily_Minutes_Spent  1000 non-null   int64
#  3   Posts_Per_Day        1000 non-null   int64
#  4   Likes_Per_Day        1000 non-null   int64
#  5   Follows_Per_Day      1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
df1.describe()
# Out:
#        Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  Follows_Per_Day
# count          1000.000000    1000.000000    1000.000000      1000.000000
# mean            247.368000      10.269000      94.682000        24.698000
# std             146.371921       6.121774      57.560943        14.842948
# min               5.000000       0.000000       0.000000         0.000000
# 25%             112.750000       5.000000      44.750000        12.000000
# 50%             246.000000      10.000000      94.000000        24.000000
# 75%             380.500000      16.000000     142.000000        38.000000
# max             500.000000      20.000000     200.000000        50.000000

# %%
df1.shape
# Out:
# (1000, 6)

# %%
df1.isnull().sum()
# Out:
# User_ID                0
# App                    0
# Daily_Minutes_Spent    0
# Posts_Per_Day          0
# Likes_Per_Day          0
# Follows_Per_Day        0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
numeric_cols = df1.select_dtypes(include=['number'])

# %%
numeric_cols.corr()
# Out:
#                      Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# Daily_Minutes_Spent             1.000000      -0.023968       0.013545
# Posts_Per_Day                  -0.023968       1.000000       0.016892
# Likes_Per_Day                   0.013545       0.016892       1.000000
# Follows_Per_Day                 0.037521       0.018113      -0.017476
#
#                      Follows_Per_Day
# Daily_Minutes_Spent         0.037521
# Posts_Per_Day               0.018113
# Likes_Per_Day              -0.017476
# Follows_Per_Day             1.000000

# %%
sns.histplot(df1['Daily_Minutes_Spent'], bins=30, kde=True)
plt.title("Time Spent Per Day Distribution")
plt.show()

# %%
sns.boxplot(x=df1['Daily_Minutes_Spent'])
plt.title("Outliers in Time Spent Per Day")
plt.show()

# %%
df1['App'].unique()
# Out:
# array(['Pinterest', 'Facebook', 'Instagram', 'TikTok', 'LinkedIn',
#        'Twitter', 'Snapchat'], dtype=object)

# %%
from numpy import random

# %%
df1.head()
# Out:
#   User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0     U_1  Pinterest                  288             16             94
# 1     U_2   Facebook                  192             14            117
# 2     U_3  Instagram                  351             13            120
# 3     U_4     TikTok                   21             20            117
# 4     U_5   LinkedIn                  241             16              9
#
#    Follows_Per_Day
# 0                0
# 1               15
# 2               48
# 3                8
# 4               21

# %%
categorical_columns = df1.select_dtypes(include=['object', 'category'])

# %%
categorical_summary = categorical_columns.describe()

# %%
categorical_summary
# Out:
#        User_ID       App
# count     1000      1000
# unique    1000         7
# top        U_1  Snapchat
# freq         1       156

# %%
categorical_columns.head()
# Out:
#   User_ID        App
# 0     U_1  Pinterest
# 1     U_2   Facebook
# 2     U_3  Instagram
# 3     U_4     TikTok
# 4     U_5   LinkedIn

# %%
unique_counts = categorical_columns.nunique()

# %%
unique_counts
# Out:
# User_ID    1000
# App           7
# dtype: int64

# %%
#Frequency Distribution for Each Column
for column in categorical_columns.columns:
    print(f"Value counts for '{column}':")
    print(categorical_columns[column].value_counts())
    print()
# Out:
# Value counts for 'User_ID':
# User_ID
# U_1       1
# U_672     1
# U_659     1
# U_660     1
# U_661     1
#          ..
# U_339     1
# U_340     1
# U_341     1
# U_342     1
# U_1000    1
# Name: count, Length: 1000, dtype: int64
#
# Value counts for 'App':
# App
# Snapchat     156
# LinkedIn     147
# TikTok       141
# Pinterest    140
# Instagram    140
# Twitter      140
# Facebook     136
# Name: count, dtype: int64

# %%
# Select numeric columns
numeric_columns = df1.select_dtypes(include=['number'])
print(numeric_columns.head())
# Out:
#    Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  Follows_Per_Day
# 0                  288             16             94                0
# 1                  192             14            117               15
# 2                  351             13            120               48
# 3                   21             20            117                8
# 4                  241             16              9               21

# %%
numeric_columns.hist(bins=20, figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# Plot boxplots for numeric columns
numeric_columns.plot(kind='box', figsize=(8, 6))
plt.title('Box Plot of Usage Metrics')
plt.show()

# %%
df1['Daily_Minutes_Spent'].describe()
# Out:
# count    1000.000000
# mean      247.368000
# std       146.371921
# min         5.000000
# 25%       112.750000
# 50%       246.000000
# 75%       380.500000
# max       500.000000
# Name: Daily_Minutes_Spent, dtype: float64

# %%
df1['Posts_Per_Day'].describe()
# Out:
# count    1000.000000
# mean       10.269000
# std         6.121774
# min         0.000000
# 25%         5.000000
# 50%        10.000000
# 75%        16.000000
# max        20.000000
# Name: Posts_Per_Day, dtype: float64

# %%
df1['Likes_Per_Day'].describe()
# Out:
# count    1000.000000
# mean       94.682000
# std        57.560943
# min         0.000000
# 25%        44.750000
# 50%        94.000000
# 75%       142.000000
# max       200.000000
# Name: Likes_Per_Day, dtype: float64

# %%
df1['Follows_Per_Day'].describe()
# Out:
# count    1000.000000
# mean       24.698000
# std        14.842948
# min         0.000000
# 25%        12.000000
# 50%        24.000000
# 75%        38.000000
# max        50.000000
# Name: Follows_Per_Day, dtype: float64

# %%
df1.head()
# Out:
#   User_ID        App  Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# 0     U_1  Pinterest                  288             16             94
# 1     U_2   Facebook                  192             14            117
# 2     U_3  Instagram                  351             13            120
# 3     U_4     TikTok                   21             20            117
# 4     U_5   LinkedIn                  241             16              9
#
#    Follows_Per_Day
# 0                0
# 1               15
# 2               48
# 3                8
# 4               21

# %%
# Correlation matrix
correlation_matrix = numeric_columns.corr()
print(correlation_matrix)
# Out:
#                      Daily_Minutes_Spent  Posts_Per_Day  Likes_Per_Day  \
# Daily_Minutes_Spent             1.000000      -0.023968       0.013545
# Posts_Per_Day                  -0.023968       1.000000       0.016892
# Likes_Per_Day                   0.013545       0.016892       1.000000
# Follows_Per_Day                 0.037521       0.018113      -0.017476
#
#                      Follows_Per_Day
# Daily_Minutes_Spent         0.037521
# Posts_Per_Day               0.018113
# Likes_Per_Day              -0.017476
# Follows_Per_Day             1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Usage Metrics')
plt.show()

# %%
# Example: Segment users by Usage Time
df1['Usage Category'] = pd.cut(df1['Daily_Minutes_Spent'], bins=[0, 10, 30, 60, np.inf], labels=['Low', 'Medium', 'High', 'Very High'])
print(df1['Usage Category'].value_counts())
# Out:
# Usage Category
# Very High    873
# High          63
# Medium        48
# Low           16
# Name: count, dtype: int64

# %%
#Use pairplot to visualize relationships between pairs of metrics
sns.pairplot(numeric_columns)
plt.title("Pairwise Plot of Usage Metrics")
plt.show()

# %%
# Example: Segment users by Usage Time
df1['Usage Category'] = pd.cut(df1['Daily_Minutes_Spent'], bins=[0, 10, 30, 60, np.inf], labels=['Low', 'Medium', 'High', 'Very High'])
print(df1['Usage Category'].value_counts())
# Out:
# Usage Category
# Very High    873
# High          63
# Medium        48
# Low           16
# Name: count, dtype: int64

# %%
# Use pie charts or bar plots to display the distribution of user segments.
df1['Usage Category'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6, 6))
plt.title("User Interaction Levels")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df1['Daily_Minutes_Spent'], bins=30, kde=True, color='blue')
plt.title('Distribution of Daily Minutes Spent')
plt.xlabel('Daily Minutes Spent')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Posts_Per_Day', data=df1, palette='viridis')
plt.title('Distribution of Posts Per Day')
plt.xlabel('Posts Per Day')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_11592\2810769841.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Posts_Per_Day', data=df1, palette='viridis')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='App', y='Posts_Per_Day', data=df1, palette='Set3')
plt.title('Posts Per Day by Social Media App')
plt.xlabel('Social Media App')
plt.ylabel('Posts Per Day')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_11592\2484848590.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='App', y='Posts_Per_Day', data=df1, palette='Set3')
